# %%
import pandas as pd
import numpy as np

#détaillons les cinq premières lignes du dataset test
test = pd.read_csv("test.csv")
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#détaillons les cinq premières lignes du dataset train
train = pd.read_csv("train.csv")
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# la longueur des deux datasets test
print(len(test))
# Out:
# 1459

# %%
# la longueur du dataset train
train.shape[0]
# Out:
# 1460

# %%
#les informations sur les donneées de test
print("les informations sur les données de test")
test.info()

# %%
#informatrion sur les données de train
print("les informations sur les données d'entrainements")
train.info()
# Out:
# les informations sur les données d'entrainements
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
# ...

# %%
#les valeurs manquantes pour chaque colonnes et leur pourcentage du dataset test
valeur_manquante = test.isnull().sum()

#le pourcentage des valeurs manquantes
pourcentage_manquante = (valeur_manquante/len(test))*100

resultat = pd.DataFrame({'valeur manquante': valeur_manquante,
                        'pourcentage de valeur manquante': pourcentage_manquante})

resultat
# Out:
#                valeur manquante  pourcentage de valeur manquante
# Id                            0                         0.000000
# MSSubClass                    0                         0.000000
# MSZoning                      4                         0.274160
# LotFrontage                 227                        15.558602
# LotArea                       0                         0.000000
# ...                         ...                              ...
# MiscVal                       0                         0.000000
# MoSold                        0                         0.000000
# YrSold                        0                         0.000000
# SaleType                      1                         0.068540
# SaleCondition                 0                         0.000000
#
# [80 rows x 2 columns]

# %%
#les valeurs manquantes pour chaque colonnes et leur pourcentage du dataset d'entrainement
valeur_manquante = train.isnull().sum()

#le pourcentage des valeurs manquantes
pourcentage_manquante = (valeur_manquante/len(test))*100

resultat = pd.DataFrame({'valeur manquante': valeur_manquante,
                        'pourcentage de valeur manquante': pourcentage_manquante})

resultat
# Out:
#                valeur manquante  pourcentage de valeur manquante
# Id                            0                         0.000000
# MSSubClass                    0                         0.000000
# MSZoning                      0                         0.000000
# LotFrontage                 259                        17.751885
# LotArea                       0                         0.000000
# ...                         ...                              ...
# MoSold                        0                         0.000000
# YrSold                        0                         0.000000
# SaleType                      0                         0.000000
# SaleCondition                 0                         0.000000
# SalePrice                     0                         0.000000
#
# [81 rows x 2 columns]

# %%
#Affichez des tableaux de statistiques descriptives pour les données de Test (moyennes, médianes,écarts-types)

stat = test.describe()
stat.loc["mediane"] = stat.median()
stat
# Out:
#                   Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count    1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean     2190.000000    57.378341    68.580357   9819.161069     6.078821
# std       421.321334    42.746880    22.376841   4955.517327     1.436812
# min      1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%      1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%      2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%      2554.500000    70.000000    80.000000  11517.500000     7.000000
# max      2919.000000   190.000000   200.000000  56600.000000    10.000000
# mediane  2007.750000    53.689171    67.790179   8395.000000     6.039411
#
#          OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count    1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean        5.553804  1971.357779   1983.662783   100.709141   439.203704
# ...

# %%
#remplacement des valeurs manquantes par le mode
for i in test.columns:
    if test[i].isna().sum()>0:
        test[i] = test[i].fillna(test[i].mode()[0])
       

test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave  Grvl      Reg
# 1     1462          20       RL         81.0    14267   Pave  Grvl      IR1
# 2     1463          60       RL         74.0    13830   Pave  Grvl      IR1
# 3     1464          60       RL         78.0     9978   Pave  Grvl      IR1
# 4     1465         120       RL         43.0     5005   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave  Grvl      Reg
# 1455  2916         160       RM         21.0     1894   Pave  Grvl      Reg
# 1456  2917          20       RL        160.0    20000   Pave  Grvl      Reg
# 1457  2918          85       RL         62.0    10441   Pave  Grvl      Reg
# 1458  2919          60       RL         74.0     9627   Pave  Grvl      Reg
#
# ...

# %%
#remplacement des valeurs null par le mode
for i in train.columns:
    if train[i].isna().sum()>0:
        train[i] = train[i].fillna(train[i].mode()[0])

train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Grvl      Reg
# 1456  1457          20       RL         85.0    13175   Pave  Grvl      Reg
# 1457  1458          70       RL         66.0     9042   Pave  Grvl      Reg
# 1458  1459          20       RL         68.0     9717   Pave  Grvl      Reg
# 1459  1460          20       RL         75.0     9937   Pave  Grvl      Reg
#
# ...

# %%
#partie applicative de la partie 1

#sauvegarde du fichier nettoyé
test.to_csv("test_nettoye.csv", index =False)
print("le fichier est nettoyé et enregistré sous 'test_nettoye.csv'.")
# Out:
# le fichier est nettoyé et enregistré sous 'test_nettoye.csv'.

# %%
#calcul de la correlation entre les variables
test = pd.read_csv("test_nettoye.csv")
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  Grvl      Reg
# 1  1462          20       RL         81.0    14267   Pave  Grvl      IR1
# 2  1463          60       RL         74.0    13830   Pave  Grvl      IR1
# 3  1464          60       RL         78.0     9978   Pave  Grvl      IR1
# 4  1465         120       RL         43.0     5005   Pave  Grvl      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0     Ex  MnPrv        Shed
# 1         Lvl    AllPub  ...           0        0     Ex  MnPrv        Gar2
# 2         Lvl    AllPub  ...           0        0     Ex  MnPrv        Shed
# 3         Lvl    AllPub  ...           0        0     Ex  MnPrv        Shed
# 4         HLS    AllPub  ...         144        0     Ex  MnPrv        Shed
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#convertissons les valeurs categorielles en valeur numerique 

from sklearn.preprocessing import LabelEncoder

# Identifier les colonnes catégorielles (de type object ou category)
categorical_columns = test.select_dtypes(include=['object']).columns

# Création du LabelEncoder
label_encoder = LabelEncoder()

# Appliquer l'encodage à la colonne 'RH'
df['RH_encoded'] = label_encoder.fit_transform(df['RH'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RH'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 9
#       6 label_encoder = LabelEncoder()
# ...
